# %%
# !nvidia-smi
# Out:
# Sun Dec 28 13:25:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A40                     On  |   00000000:E3:00.0 Off |                    0 |
# |  0%   27C    P8             30W /  300W |       0MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !df -h
# Out:
# Filesystem                                                                                                                                                                                    Size  Used Avail Use% Mounted on
# overlay                                                                                                                                                                                       893G  711G  182G  80% /
# tmpfs                                                                                                                                                                                          64M     0   64M   0% /dev
# tmpfs                                                                                                                                                                                         252G     0  252G   0% /sys/fs/cgroup
# ...

# %%
# !du -ah ~ | sort -rh | head -10
# Out:
# 9.7G	/home/jovyan
# 8.6G	/home/jovyan/.cache/pip/http-v2
# 8.6G	/home/jovyan/.cache/pip
# 8.6G	/home/jovyan/.cache
# 2.3G	/home/jovyan/.cache/pip/http-v2/3
# 1.3G	/home/jovyan/.cache/pip/http-v2/e
# 1.2G	/home/jovyan/.cache/pip/http-v2/5
# 1021M	/home/jovyan/.cache/pip/http-v2/3/6
# 1009M	/home/jovyan/.cache/pip/http-v2/2
# 859M	/home/jovyan/.cache/pip/http-v2/e/c/a/e/0/ecae09356807a6385e5bea11b0bbe23f48f8bfdc7e785e460a49f328.body
# sort: write failed: 'standard output': Broken pipe
# sort: write error
