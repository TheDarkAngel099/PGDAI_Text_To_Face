# %%
from scipy.io import loadmat

data = loadmat('iiscifd_color_images.mat')
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'iiscifd', 'images', 'imnames'])

# %%
data['images'][0][0]
# Out:
# array([[[227, 234, 216],
#         [242, 252, 228],
#         [231, 244, 214],
#         ...,
#         [201, 184, 166],
#         [222, 205, 185],
#         [218, 203, 180]],
#
#        [[245, 252, 236],
#         [251, 255, 239],
#         [238, 251, 223],
#         ...,
#         [177, 160, 140],
#         [209, 193, 170],
#         [221, 206, 183]],
#
#        [[249, 255, 241],
#         [247, 255, 239],
#         [239, 251, 227],
#         ...,
#         [154, 138, 113],
#         [189, 173, 150],
#         [212, 196, 173]],
#
#        ...,
#
#        [[252, 251, 249],
#         [241, 239, 240],
#         [234, 234, 236],
#         ...,
#         [254, 255, 249],
#         [254, 255, 249],
#         [254, 255, 249]],
#
#        [[248, 247, 245],
#         [239, 237, 238],
#         [230, 230, 232],
#         ...,
#         [254, 255, 249],
#         [254, 255, 249],
#         [254, 255, 249]],
#
#        [[236, 235, 233],
#         [249, 247, 248],
#         [250, 250, 252],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data['images'][0][6])

# %%
from PIL import Image
import numpy as np
for i in range(251):
  img = data['images'][0][i]
  img_pil = Image.fromarray(img)
  img_320 = img_pil.resize((320, 320), Image.BILINEAR)
  plt.imsave(f'output/{i+1}.jpg',img_320)
